# %%
import sys
import os
sys.path.append(os.path.abspath("../CODE"))
from plotly_plotting import *

# %%
plot_maxi_hid(mjd_low=60570, mjd_high=60660, plotly= True, show_errobars = True, mjds_to_point_to = None, xlim = (1e-1,3e0), ylim = (2e-2,2e-1), hr_unc_cutoff = 1)
